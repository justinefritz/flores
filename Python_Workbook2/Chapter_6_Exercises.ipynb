# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Given the code below
#
#     text = 'Business Analytics'
#
# What will the following expressions produce?
#
#     text[4]
#     text[2:4]
#     text[:4]
#     text[4:]
#     text[-2]
#     text[-4:-2]
#     text[-2:]
#     text[:-2]

# %%
text = 'Business Analytics'
print(text[4]) # will print the 5th character
print(text[2:4]) # will print the 3rd to 4th character
print(text[:4]) # will print all character before the 4th character
print(text[4:]) # will print the all character starting after the 5th character
print(text[-2]) # will print the 2nd to the last character
print(text[-4:-2]) # will print the 4th to 3rd to the last character
print(text[-2:]) # will print the all character after the 2nd to the last character
print(text[:-2]) # will print the all character before the 2nd to the last character
# Out:
# n
# si
# Busi
# ness Analytics
# c
# ti
# cs
# Business Analyti

# %% [markdown]
# #### Exercise 2

# %% [markdown]
# Given the code below:
#
#     phrase = 'One Ring to rule them all'
#
# What string slicing expression gives out the following words:
#
#     'One '
#     'Ring'
#     'all'
#     'them'
#     'One Ring to rule them all'

# %%
phrase = 'One Ring to rule them all'
print(phrase[:4])
print(phrase[4:8])
print(phrase[-3:])
print(phrase[-8:-4])
print(phrase)
# Out:
# One
# Ring
# all
# them
# One Ring to rule them all

# %% [markdown]
# ## CHALLENGE

# %% [markdown]
# Write a program which repeatedly reads a **full name**, then does the following:
# - strips the name of any trailing spaces
# - capitalizes the first letter
# - puts the rest into smaller letters

# %%
name = input("Enter your name : ")
i = 0

new_name = name.strip()
new_name = new_name.lower()
new_name = new_name.capitalize()

for char in new_name:
  if char == ' ':
    letter = new_name[i+1].capitalize()
    new_name = new_name[:i+1] + letter + new_name[i+2:]
  i = i + 1
print(new_name)
# Out:
# Enter your name : justine fritz i. flores
# Justine Fritz I. Flores
